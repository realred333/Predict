# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os

# %matplotlib inline
warnings.filterwarnings('ignore')

plt.rcParams['font.family'] = 'NanumGothic'

# %%
import FinanceDataReader as fdr

stock = fdr.DataReader('041930', '2016')

# %%
stock['Year'] = stock.index.year
stock['Month'] = stock.index.month
stock['Day'] = stock.index.day

# %%
plt.figure(figsize=(16,9))
sns.lineplot(y=stock['Close'], x=stock.index)
plt.xlabel('time')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
# 스케일을 적용할 column을 정의합니다.
scale_cols = ['Open', 'High', 'Low', 'Close', 'Volume']
# 스케일 후 columns
scaled = scaler.fit_transform(stock[scale_cols])
scaled
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0986dbc0123c> in <module>
#       5 scale_cols = ['Open', 'High', 'Low', 'Close', 'Volume']
#       6 # 스케일 후 columns
# ----> 7 scaled = scaler.fit_transform(stock[scale_cols])
#       8 scaled
#
# NameError: name 'stock' is not defined

# %%
df = pd.DataFrame(scaled, columns=scale_cols)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(df.drop('Close', 1), df['Close'], test_size=0.2, random_state=0, shuffle=False)

x_train.shape, y_train.shape
# Out:
# ((1073, 4), (1073,))

# %%
x_test.shape, y_test.shape
# Out:
# ((269, 4), (269,))

# %%
x_train
# Out:
#           Open      High       Low    Volume
# 0     0.196613  0.176005  0.209867  0.002520
# 1     0.203240  0.174687  0.209867  0.002614
# 2     0.202504  0.179301  0.214421  0.001366
# 3     0.209131  0.179301  0.206072  0.001878
# 4     0.201031  0.172709  0.204554  0.000779
# ...        ...       ...       ...       ...
# 1068  0.190722  0.160185  0.188235  0.008939
# 1069  0.187776  0.160844  0.191271  0.004925
# 1070  0.187040  0.168754  0.193169  0.021600
# 1071  0.201031  0.169413  0.203795  0.017681
# 1072  0.198822  0.175346  0.207590  0.018195
#
# [1073 rows x 4 columns]

# %%
import tensorflow as tf

# %%
def windowed_dataset(series, window_size, batch_size, shuffle):
    series = tf.expand_dims(series, axis=-1)
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    if shuffle:
        ds = ds.shuffle(1000)
    ds = ds.map(lambda w: (w[:-1], w[-1]))
    return ds.batch(batch_size).prefetch(1)

# %%
WINDOW_SIZE = 20
BATCH_SIZE = 32

# %%
# trian_data는 학습용 데이터셋, test_data는 검증용 데이터셋 입니다.
train_data = windowed_dataset(y_train, WINDOW_SIZE, BATCH_SIZE, False)
test_data = windowed_dataset(y_test, WINDOW_SIZE, BATCH_SIZE, False)

# %%
# 아래의 코드로 데이터셋의 구성을 확인해 볼 수 있습니다.
# X: (batch_size, window_size, feature)
# Y: (batch_size, feature)
for data in train_data.take(1):
    print(f'데이터셋(X) 구성(batch_size, window_size, feature갯수): {data[0].shape}')
    print(f'데이터셋(Y) 구성(batch_size, window_size, feature갯수): {data[1].shape}')
# Out:
# 데이터셋(X) 구성(batch_size, window_size, feature갯수): (32, 20, 1)
# 데이터셋(Y) 구성(batch_size, window_size, feature갯수): (32, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Conv1D, Lambda
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.losses import Huber

model = Sequential([
    # 1차원 feature map 생성
    Conv1D(filters=32, kernel_size=5,
           padding="causal",
           activation="relu",
           input_shape=[WINDOW_SIZE, 1]),
    # LSTM
    LSTM(50, return_sequences=True, input_shape=(50, 1)),
    LSTM(64, return_sequences=False),
    Dense(1, activation='linear'),
    #LSTM(16, activation='tanh'),
    #Dense(16, activation="relu"),
    #Dense(1),
])

# %%
# Sequence 학습에 비교적 좋은 퍼포먼스를 내는 Huber()를 사용합니다.
loss = Huber()
optimizer = Adam(0.0005)
model.compile(loss=Huber(), optimizer=optimizer, metrics=['mse'])

# %%
# val_loss 기준 체크포인터도 생성합니다.
filename = os.path.join('tmp', 'ckeckpointer.ckpt')
checkpoint = ModelCheckpoint(filename, 
                             save_weights_only=True, 
                             save_best_only=True, 
                             monitor='val_loss', 
                             verbose=1)

# earlystopping은 10번 epoch통안 val_loss 개선이 없다면 학습을 멈춥니다.
earlystopping = EarlyStopping(monitor='val_loss', patience=10)

# %%
history = model.fit(train_data,
                    validation_data=(test_data), 
                    epochs=50, 
                    callbacks=[checkpoint, earlystopping], 
                   )
# Out:
# Epoch 1/50
# 33/33 [==============================] - 6s 59ms/step - loss: 0.0050 - mse: 0.0100 - val_loss: 0.0528 - val_mse: 0.1056
#
# Epoch 00001: val_loss improved from inf to 0.05282, saving model to tmp/ckeckpointer.ckpt
# Epoch 2/50
# 33/33 [==============================] - 1s 31ms/step - loss: 0.0011 - mse: 0.0023 - val_loss: 0.0330 - val_mse: 0.0660
#
# Epoch 00002: val_loss improved from 0.05282 to 0.03301, saving model to tmp/ckeckpointer.ckpt
# Epoch 3/50
# 33/33 [==============================] - 1s 32ms/step - loss: 9.5245e-04 - mse: 0.0019 - val_loss: 0.0201 - val_mse: 0.0402
#
# Epoch 00003: val_loss improved from 0.03301 to 0.02008, saving model to tmp/ckeckpointer.ckpt
# Epoch 4/50
# 33/33 [==============================] - 1s 32ms/step - loss: 7.8758e-04 - mse: 0.0016 - val_loss: 0.0129 - val_mse: 0.0257
#
# Epoch 00004: val_loss improved from 0.02008 to 0.01287, saving model to tmp/ckeckpointer.ckpt
# Epoch 5/50
# 33/33 [==============================] - 1s 32ms/step - loss: 6.3402e-04 - mse: 0.0013 - val_loss: 0.0089 - val_mse: 0.0177
#
# Epoch 00005: val_loss improved from 0.01287 to 0.00886, saving model to tmp/ckeckpointer.ckpt
# Epoch 6/50
# 33/33 [==============================] - 1s 34ms/step - loss: 5.0176e-04 - mse: 0.0010 - val_loss: 0.0071 - val_mse: 0.0141
#
# Epoch 00006: val_loss improved from 0.00886 to 0.00706, saving model to tmp/ckeckpointer.ckpt
# Epoch 7/50
# 33/33 [==============================] - 1s 32ms/step - loss: 4.3389e-04 - mse: 8.6779e-04 - val_loss: 0.0066 - val_mse: 0.0131
#
# Epoch 00007: val_loss improved from 0.00706 to 0.00656, saving model to tmp/ckeckpointer.ckpt
# Epoch 8/50
# 33/33 [==============================] - 1s 32ms/step - loss: 4.0244e-04 - mse: 8.0488e-04 - val_loss: 0.0065 - val_mse: 0.0130
#
# Epoch 00008: val_loss improved from 0.00656 to 0.00652, saving model to tmp/ckeckpointer.ckpt
# Epoch 9/50
# 33/33 [==============================] - 1s 33ms/step - loss: 3.8650e-04 - mse: 7.7301e-04 - val_loss: 0.0060 - val_mse: 0.0119
#
# Epoch 00009: val_loss improved from 0.00652 to 0.00596, saving model to tmp/ckeckpointer.ckpt
# Epoch 10/50
# 33/33 [==============================] - 1s 33ms/step - loss: 3.6698e-04 - mse: 7.3397e-04 - val_loss: 0.0053 - val_mse: 0.0107
#
# Epoch 00010: val_loss improved from 0.00596 to 0.00533, saving model to tmp/ckeckpointer.ckpt
# Epoch 11/50
# 33/33 [==============================] - 1s 33ms/step - loss: 3.5101e-04 - mse: 7.0202e-04 - val_loss: 0.0048 - val_mse: 0.0096
#
# Epoch 00011: val_loss improved from 0.00533 to 0.00480, saving model to tmp/ckeckpointer.ckpt
# Epoch 12/50
# 33/33 [==============================] - 1s 32ms/step - loss: 3.3388e-04 - mse: 6.6776e-04 - val_loss: 0.0043 - val_mse: 0.0087
#
# Epoch 00012: val_loss improved from 0.00480 to 0.00433, saving model to tmp/ckeckpointer.ckpt
# Epoch 13/50
# 33/33 [==============================] - 1s 32ms/step - loss: 3.1937e-04 - mse: 6.3874e-04 - val_loss: 0.0039 - val_mse: 0.0077
#
# Epoch 00013: val_loss improved from 0.00433 to 0.00386, saving model to tmp/ckeckpointer.ckpt
# Epoch 14/50
# 33/33 [==============================] - 1s 32ms/step - loss: 3.0397e-04 - mse: 6.0793e-04 - val_loss: 0.0034 - val_mse: 0.0067
#
# Epoch 00014: val_loss improved from 0.00386 to 0.00335, saving model to tmp/ckeckpointer.ckpt
# Epoch 15/50
# 33/33 [==============================] - 1s 32ms/step - loss: 2.8810e-04 - mse: 5.7619e-04 - val_loss: 0.0031 - val_mse: 0.0062
#
# Epoch 00015: val_loss improved from 0.00335 to 0.00312, saving model to tmp/ckeckpointer.ckpt
# Epoch 16/50
# 33/33 [==============================] - 1s 32ms/step - loss: 2.7747e-04 - mse: 5.5494e-04 - val_loss: 0.0027 - val_mse: 0.0054
#
# Epoch 00016: val_loss improved from 0.00312 to 0.00268, saving model to tmp/ckeckpointer.ckpt
# Epoch 17/50
# 33/33 [==============================] - 1s 32ms/step - loss: 2.6278e-04 - mse: 5.2555e-04 - val_loss: 0.0025 - val_mse: 0.0050
#
# Epoch 00017: val_loss improved from 0.00268 to 0.00252, saving model to tmp/ckeckpointer.ckpt
# Epoch 18/50
# 33/33 [==============================] - 1s 32ms/step - loss: 2.5374e-04 - mse: 5.0748e-04 - val_loss: 0.0022 - val_mse: 0.0044
#
# Epoch 00018: val_loss improved from 0.00252 to 0.00222, saving model to tmp/ckeckpointer.ckpt
# Epoch 19/50
# 33/33 [==============================] - 1s 32ms/step - loss: 2.4075e-04 - mse: 4.8149e-04 - val_loss: 0.0021 - val_mse: 0.0043
#
# Epoch 00019: val_loss improved from 0.00222 to 0.00213, saving model to tmp/ckeckpointer.ckpt
# Epoch 20/50
# 33/33 [==============================] - 1s 32ms/step - loss: 2.3295e-04 - mse: 4.6590e-04 - val_loss: 0.0019 - val_mse: 0.0038
#
# Epoch 00020: val_loss improved from 0.00213 to 0.00190, saving model to tmp/ckeckpointer.ckpt
# Epoch 21/50
# 33/33 [==============================] - 1s 32ms/step - loss: 2.2095e-04 - mse: 4.4190e-04 - val_loss: 0.0019 - val_mse: 0.0037
#
# Epoch 00021: val_loss improved from 0.00190 to 0.00187, saving model to tmp/ckeckpointer.ckpt
# Epoch 22/50
# 33/33 [==============================] - 1s 33ms/step - loss: 2.1399e-04 - mse: 4.2797e-04 - val_loss: 0.0017 - val_mse: 0.0034
#
# Epoch 00022: val_loss improved from 0.00187 to 0.00169, saving model to tmp/ckeckpointer.ckpt
# Epoch 23/50
# 33/33 [==============================] - 1s 35ms/step - loss: 2.0225e-04 - mse: 4.0451e-04 - val_loss: 0.0017 - val_mse: 0.0034
#
# Epoch 00023: val_loss did not improve from 0.00169
# Epoch 24/50
# 33/33 [==============================] - 2s 48ms/step - loss: 1.9598e-04 - mse: 3.9195e-04 - val_loss: 0.0016 - val_mse: 0.0031
#
# Epoch 00024: val_loss improved from 0.00169 to 0.00157, saving model to tmp/ckeckpointer.ckpt
# Epoch 25/50
# 33/33 [==============================] - 2s 48ms/step - loss: 1.8455e-04 - mse: 3.6910e-04 - val_loss: 0.0016 - val_mse: 0.0032
#
# Epoch 00025: val_loss did not improve from 0.00157
# Epoch 26/50
# 33/33 [==============================] - 1s 42ms/step - loss: 1.7942e-04 - mse: 3.5884e-04 - val_loss: 0.0014 - val_mse: 0.0029
#
# Epoch 00026: val_loss improved from 0.00157 to 0.00145, saving model to tmp/ckeckpointer.ckpt
# Epoch 27/50
# 33/33 [==============================] - 1s 40ms/step - loss: 1.6820e-04 - mse: 3.3640e-04 - val_loss: 0.0015 - val_mse: 0.0030
#
# Epoch 00027: val_loss did not improve from 0.00145
# Epoch 28/50
# 33/33 [==============================] - 1s 35ms/step - loss: 1.6389e-04 - mse: 3.2777e-04 - val_loss: 0.0014 - val_mse: 0.0027
#
# Epoch 00028: val_loss improved from 0.00145 to 0.00136, saving model to tmp/ckeckpointer.ckpt
# Epoch 29/50
# 33/33 [==============================] - 1s 33ms/step - loss: 1.5170e-04 - mse: 3.0341e-04 - val_loss: 0.0016 - val_mse: 0.0032
#
# Epoch 00029: val_loss did not improve from 0.00136
# Epoch 30/50
# 33/33 [==============================] - 1s 35ms/step - loss: 1.5019e-04 - mse: 3.0038e-04 - val_loss: 0.0014 - val_mse: 0.0027
#
# Epoch 00030: val_loss improved from 0.00136 to 0.00135, saving model to tmp/ckeckpointer.ckpt
# Epoch 31/50
# 33/33 [==============================] - 1s 33ms/step - loss: 1.3949e-04 - mse: 2.7897e-04 - val_loss: 0.0015 - val_mse: 0.0031
#
# Epoch 00031: val_loss did not improve from 0.00135
# Epoch 32/50
# 33/33 [==============================] - 1s 43ms/step - loss: 1.3973e-04 - mse: 2.7945e-04 - val_loss: 0.0013 - val_mse: 0.0025
#
# Epoch 00032: val_loss improved from 0.00135 to 0.00126, saving model to tmp/ckeckpointer.ckpt
# Epoch 33/50
# 33/33 [==============================] - 1s 38ms/step - loss: 1.2904e-04 - mse: 2.5807e-04 - val_loss: 0.0015 - val_mse: 0.0030
#
# Epoch 00033: val_loss did not improve from 0.00126
# Epoch 34/50
# 33/33 [==============================] - 1s 33ms/step - loss: 1.3127e-04 - mse: 2.6255e-04 - val_loss: 0.0012 - val_mse: 0.0024
#
# Epoch 00034: val_loss improved from 0.00126 to 0.00122, saving model to tmp/ckeckpointer.ckpt
# Epoch 35/50
# 33/33 [==============================] - 1s 39ms/step - loss: 1.2134e-04 - mse: 2.4269e-04 - val_loss: 0.0016 - val_mse: 0.0031
#
# Epoch 00035: val_loss did not improve from 0.00122
# Epoch 36/50
# 33/33 [==============================] - 1s 37ms/step - loss: 1.2744e-04 - mse: 2.5489e-04 - val_loss: 0.0012 - val_mse: 0.0023
#
# Epoch 00036: val_loss improved from 0.00122 to 0.00115, saving model to tmp/ckeckpointer.ckpt
# Epoch 37/50
# 33/33 [==============================] - 1s 39ms/step - loss: 1.1507e-04 - mse: 2.3015e-04 - val_loss: 0.0018 - val_mse: 0.0035
#
# Epoch 00037: val_loss did not improve from 0.00115
# Epoch 38/50
# 33/33 [==============================] - 1s 36ms/step - loss: 1.2697e-04 - mse: 2.5394e-04 - val_loss: 0.0011 - val_mse: 0.0022
#
# Epoch 00038: val_loss improved from 0.00115 to 0.00112, saving model to tmp/ckeckpointer.ckpt
# Epoch 39/50
# 33/33 [==============================] - 1s 36ms/step - loss: 1.1063e-04 - mse: 2.2126e-04 - val_loss: 0.0022 - val_mse: 0.0043
#
# Epoch 00039: val_loss did not improve from 0.00112
# Epoch 40/50
# 33/33 [==============================] - 1s 39ms/step - loss: 1.3036e-04 - mse: 2.6071e-04 - val_loss: 0.0012 - val_mse: 0.0023
#
# Epoch 00040: val_loss did not improve from 0.00112
# Epoch 41/50
# 33/33 [==============================] - 1s 37ms/step - loss: 1.0782e-04 - mse: 2.1563e-04 - val_loss: 0.0030 - val_mse: 0.0060
#
# Epoch 00041: val_loss did not improve from 0.00112
# Epoch 42/50
# 33/33 [==============================] - 1s 37ms/step - loss: 1.4140e-04 - mse: 2.8281e-04 - val_loss: 0.0013 - val_mse: 0.0026
#
# Epoch 00042: val_loss did not improve from 0.00112
# Epoch 43/50
# 33/33 [==============================] - 1s 35ms/step - loss: 1.0949e-04 - mse: 2.1898e-04 - val_loss: 0.0047 - val_mse: 0.0093
#
# Epoch 00043: val_loss did not improve from 0.00112
# Epoch 44/50
# 33/33 [==============================] - 1s 36ms/step - loss: 1.6908e-04 - mse: 3.3816e-04 - val_loss: 0.0015 - val_mse: 0.0029
#
# Epoch 00044: val_loss did not improve from 0.00112
# Epoch 45/50
# 33/33 [==============================] - 1s 39ms/step - loss: 1.2390e-04 - mse: 2.4780e-04 - val_loss: 0.0078 - val_mse: 0.0155
#
# Epoch 00045: val_loss did not improve from 0.00112
# Epoch 46/50
# 33/33 [==============================] - 1s 36ms/step - loss: 2.3852e-04 - mse: 4.7705e-04 - val_loss: 0.0014 - val_mse: 0.0028
#
# Epoch 00046: val_loss did not improve from 0.00112
# Epoch 47/50
# 33/33 [==============================] - 1s 36ms/step - loss: 1.5707e-04 - mse: 3.1413e-04 - val_loss: 0.0102 - val_mse: 0.0205
#
# Epoch 00047: val_loss did not improve from 0.00112
# Epoch 48/50
# 33/33 [==============================] - 1s 37ms/step - loss: 3.3760e-04 - mse: 6.7520e-04 - val_loss: 0.0011 - val_mse: 0.0021
#
# Epoch 00048: val_loss improved from 0.00112 to 0.00106, saving model to tmp/ckeckpointer.ckpt
# Epoch 49/50
# 33/33 [==============================] - 1s 36ms/step - loss: 1.5411e-04 - mse: 3.0821e-04 - val_loss: 0.0039 - val_mse: 0.0077
#
# Epoch 00049: val_loss did not improve from 0.00106
# Epoch 50/50
# 33/33 [==============================] - 1s 35ms/step - loss: 1.8551e-04 - mse: 3.7103e-04 - val_loss: 9.5808e-04 - val_mse: 0.0019
#
# Epoch 00050: val_loss improved from 0.00106 to 0.00096, saving model to tmp/ckeckpointer.ckpt

# %%
pred = model.predict(test_data)
pred.shape
# Out:
# (249, 1)

# %%
test_predict = scaler.inverse_transform() # 금액데이터 역정규화한다
print("Tomorrow's stock price", test_predict[-1]) # 예측한 주가를 출력한다
# Out:
# Tomorrow's stock price [ 13450.  13700.  13200.  13650. 276659.]

# %%
plt.figure(figsize=(16,9))
plt.plot(np.asarray(y_test[20:]), label='actual')
plt.plot(pred, label='prediction')
plt.legend()
plt.show()

# %%
scaled[1:3][0]
# Out:
# array([0.20324006, 0.17468688, 0.20986717, 0.20930233, 0.00261425])

# %%
scaled
# Out:
# array([[0.19661267, 0.17600527, 0.20986717, 0.2108027 , 0.0025202 ],
#        [0.20324006, 0.17468688, 0.20986717, 0.20930233, 0.00261425],
#        [0.20250368, 0.17930125, 0.21442125, 0.21530383, 0.00136576],
#        ...,
#        [0.79749632, 0.7033619 , 0.81024668, 0.80870218, 0.00689276],
#        [0.78276878, 0.70995386, 0.81404175, 0.81995499, 0.00435944],
#        [0.80486009, 0.72643375, 0.81783681, 0.83495874, 0.01039434]])

# %%
test_pred = sess.run(hypothesis, feed_dict={X: recent_data})
